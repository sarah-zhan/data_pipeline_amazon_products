# %%
import pandas as pd

df = pd.read_csv("amazon_products.csv")
df.head()
# Out:
#          asin                                              title  \
# 0  B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1  B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2  B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3  B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4  B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/815dLQKYIY...
# 1  https://m.media-amazon.com/images/I/81bQlm7vf6...
# 2  https://m.media-amazon.com/images/I/71EA35zvJB...
# 3  https://m.media-amazon.com/images/I/91k6NYLQyI...
# 4  https://m.media-amazon.com/images/I/61NJoaZcP9...
#
#                              productURL  stars  reviews   price  listPrice  \
# 0  https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99       0.00
# 1  https://www.amazon.com/dp/B07GDLCQXV    4.5        0  169.99     209.99
# 2  https://www.amazon.com/dp/B07XSCCZYG    4.6        0  365.49     429.99
# 3  https://www.amazon.com/dp/B08MVFKGJM    4.6        0  291.59     354.37
# 4  https://www.amazon.com/dp/B01DJLKZBA    4.5        0  174.99     309.99
#
#    category_id  isBestSeller  boughtInLastMonth
# 0          104         False               2000
# 1          104         False               1000
# 2          104         False                300
# 3          104         False                400
# 4          104         False                400

# %%
import pandas as pd
df_category = pd.read_csv('amazon_categories.csv')
df_category
# Out:
#       id                                    category_name
# 0      1                         Beading & Jewelry Making
# 1      2                                Fabric Decorating
# 2      3                      Knitting & Crochet Supplies
# 3      4                             Printmaking Supplies
# 4      5                 Scrapbooking & Stamping Supplies
# ..   ...                                              ...
# 243  262  Xbox Series X & S Consoles, Games & Accessories
# 244  263                           PC Games & Accessories
# 245  264                     Baby Girls' Clothing & Shoes
# 246  265                            Boys' School Uniforms
# 247  270                                     Toys & Games
#
# [248 rows x 2 columns]

# %%
df_columns = df.columns
df_columns
# Out:
# Index(['asin', 'title', 'imgUrl', 'productURL', 'stars', 'reviews', 'price',
#        'listPrice', 'category_id', 'isBestSeller', 'boughtInLastMonth'],
#       dtype='object')

# %%
# standardize the column names of df

import re

for col in df_columns:
    converted_col = re.sub(r'(?<=[a-z])([A-Z])', r'_\1', col).lower()
    df.rename(columns={col: converted_col}, inplace=True)

print(df.columns)
# Out:
# Index(['asin', 'title', 'img_url', 'product_url', 'stars', 'reviews', 'price',
#        'list_price', 'category_id', 'is_best_seller', 'bought_in_last_month'],
#       dtype='object')

# %%
# merge df and df_category
import pandas as pd
merge_df = pd.merge(df, df_category, left_on='category_id', right_on='id', how='left')
merge_df.drop('id', axis=1, inplace=True)

# %%
merge_df.head()
# Out:
#          asin                                              title  \
# 0  B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1  B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2  B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3  B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4  B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
#
#                                              img_url  \
# 0  https://m.media-amazon.com/images/I/815dLQKYIY...
# 1  https://m.media-amazon.com/images/I/81bQlm7vf6...
# 2  https://m.media-amazon.com/images/I/71EA35zvJB...
# 3  https://m.media-amazon.com/images/I/91k6NYLQyI...
# 4  https://m.media-amazon.com/images/I/61NJoaZcP9...
#
#                             product_url  stars  reviews   price  list_price  \
# 0  https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99        0.00
# 1  https://www.amazon.com/dp/B07GDLCQXV    4.5        0  169.99      209.99
# 2  https://www.amazon.com/dp/B07XSCCZYG    4.6        0  365.49      429.99
# 3  https://www.amazon.com/dp/B08MVFKGJM    4.6        0  291.59      354.37
# 4  https://www.amazon.com/dp/B01DJLKZBA    4.5        0  174.99      309.99
#
#    category_id  is_best_seller  bought_in_last_month category_name
# 0          104           False                  2000     Suitcases
# 1          104           False                  1000     Suitcases
# 2          104           False                   300     Suitcases
# 3          104           False                   400     Suitcases
# 4          104           False                   400     Suitcases

# %%
merge_df.to_csv('merge_df.csv', index=False)

# %%
from google.cloud import storage

def upload_to_gcs(bucket_name, file_name, destination_blob_name):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(file_name)
    print(f'File {file_name} uploaded to {destination_blob_name}.')

# set the bucket name and file name
bucket_name = 'datapipline_amazon_products'
file_name = 'merge_df.csv'
destination_blob_name = 'merge_df.csv'

upload_to_gcs(bucket_name, file_name, destination_blob_name)
# Out:
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# Cell In[11], line 15
#      12 file_name = 'merge_df.csv'
#      13 destination_blob_name = 'merge_df.csv'
# ---> 15 upload_to_gcs(bucket_name, file_name, destination_blob_name)
#
# Cell In[11], line 7, in upload_to_gcs(bucket_name, file_name, destination_blob_name)
#       5 bucket = storage_client.bucket(bucket_name)
#       6 blob = bucket.blob(destination_blob_name)
# ----> 7 blob.upload_from_filename(file_name)
#       8 print(f'File {file_name} uploaded to {destination_blob_name}.')
#
# File ~/.local/lib/python3.10/site-packages/google/cloud/storage/blob.py:2926, in Blob.upload_from_filename(self, filename, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    2804 def upload_from_filename(
#    2805     self,
#    2806     filename,
#    (...)
#    2817     retry=DEFAULT_RETRY_IF_GENERATION_SPECIFIED,
#    2818 ):
#    2819     """Upload this blob's contents from the content of a named file.
#    2820
#    2821     The content type of the upload will be determined in order
#    (...)
#    2923         are respected.
#    2924     """
# -> 2926     self._handle_filename_and_upload(
#    2927         filename,
#    2928         content_type=content_type,
#    2929         num_retries=num_retries,
#    2930         client=client,
#    2931         predefined_acl=predefined_acl,
#    2932         if_generation_match=if_generation_match,
#    2933         if_generation_not_match=if_generation_not_match,
#    2934         if_metageneration_match=if_metageneration_match,
#    2935         if_metageneration_not_match=if_metageneration_not_match,
#    2936         timeout=timeout,
#    2937         checksum=checksum,
#    2938         retry=retry,
#    2939     )
#
# File ~/.local/lib/python3.10/site-packages/google/cloud/storage/blob.py:2796, in Blob._handle_filename_and_upload(self, filename, content_type, *args, **kwargs)
#    2794 with open(filename, "rb") as file_obj:
#    2795     total_bytes = os.fstat(file_obj.fileno()).st_size
# -> 2796     self._prep_and_do_upload(
#    2797         file_obj,
#    2798         content_type=content_type,
#    2799         size=total_bytes,
#    2800         *args,
#    2801         **kwargs,
#    2802     )
#
# File ~/.local/lib/python3.10/site-packages/google/cloud/storage/blob.py:2604, in Blob._prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2601 predefined_acl = ACL.validate_predefined(predefined_acl)
#    2603 try:
# -> 2604     created_json = self._do_upload(
#    2605         client,
#    2606         file_obj,
#    2607         content_type,
#    2608         size,
#    2609         num_retries,
#    2610         predefined_acl,
#    2611         if_generation_match,
#    2612         if_generation_not_match,
#    2613         if_metageneration_match,
#    2614         if_metageneration_not_match,
#    2615         timeout=timeout,
#    2616         checksum=checksum,
#    2617         retry=retry,
#    2618         command=command,
#    2619     )
#    2620     self._set_properties(created_json)
#    2621 except resumable_media.InvalidResponse as exc:
#
# File ~/.local/lib/python3.10/site-packages/google/cloud/storage/blob.py:2427, in Blob._do_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2410     response = self._do_multipart_upload(
#    2411         client,
#    2412         stream,
#    (...)
#    2424         command=command,
#    2425     )
#    2426 else:
# -> 2427     response = self._do_resumable_upload(
#    2428         client,
#    2429         stream,
#    2430         content_type,
#    2431         size,
#    2432         num_retries,
#    2433         predefined_acl,
#    2434         if_generation_match,
#    2435         if_generation_not_match,
#    2436         if_metageneration_match,
#    2437         if_metageneration_not_match,
#    2438         timeout=timeout,
#    2439         checksum=checksum,
#    2440         retry=retry,
#    2441         command=command,
#    2442     )
#    2444 return response.json()
#
# File ~/.local/lib/python3.10/site-packages/google/cloud/storage/blob.py:2245, in Blob._do_resumable_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2131 def _do_resumable_upload(
#    2132     self,
#    2133     client,
#    (...)
#    2146     command=None,
#    2147 ):
#    2148     """Perform a resumable upload.
#    2149
#    2150     Assumes ``chunk_size`` is not :data:`None` on the current blob.
#    (...)
#    2243               is uploaded.
#    2244     """
# -> 2245     upload, transport = self._initiate_resumable_upload(
#    2246         client,
#    2247         stream,
#    2248         content_type,
#    2249         size,
#    2250         num_retries,
#    2251         predefined_acl=predefined_acl,
#    2252         if_generation_match=if_generation_match,
#    2253         if_generation_not_match=if_generation_not_match,
#    2254         if_metageneration_match=if_metageneration_match,
#    2255         if_metageneration_not_match=if_metageneration_not_match,
#    2256         timeout=timeout,
#    2257         checksum=checksum,
#    2258         retry=retry,
#    2259         command=command,
#    2260     )
#    2261     while not upload.finished:
#    2262         try:
#
# File ~/.local/lib/python3.10/site-packages/google/cloud/storage/blob.py:2119, in Blob._initiate_resumable_upload(self, client, stream, content_type, size, num_retries, predefined_acl, extra_headers, chunk_size, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2111 upload = ResumableUpload(
#    2112     upload_url, chunk_size, headers=headers, checksum=checksum
#    2113 )
#    2115 upload._retry_strategy = _api_core_retry_to_resumable_media_retry(
#    2116     retry, num_retries
#    2117 )
# -> 2119 upload.initiate(
#    2120     transport,
#    2121     stream,
#    2122     object_metadata,
#    2123     content_type,
#    2124     total_bytes=size,
#    2125     stream_final=False,
#    2126     timeout=timeout,
#    2127 )
#    2129 return upload, transport
#
# File ~/.local/lib/python3.10/site-packages/google/resumable_media/requests/upload.py:420, in ResumableUpload.initiate(self, transport, stream, metadata, content_type, total_bytes, stream_final, timeout)
#     416     self._process_initiate_response(result)
#     418     return result
# --> 420 return _request_helpers.wait_and_retry(
#     421     retriable_request, self._get_status_code, self._retry_strategy
#     422 )
#
# File ~/.local/lib/python3.10/site-packages/google/resumable_media/requests/_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     153 error = None
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#     157     error = e  # Fall through to retry, if there are retries left.
#
# File ~/.local/lib/python3.10/site-packages/google/resumable_media/requests/upload.py:412, in ResumableUpload.initiate.<locals>.retriable_request()
#     411 def retriable_request():
# --> 412     result = transport.request(
#     413         method, url, data=payload, headers=headers, timeout=timeout
#     414     )
#     416     self._process_initiate_response(result)
#     418     return result
#
# File ~/.local/lib/python3.10/site-packages/google/auth/transport/requests.py:538, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     535 remaining_time = max_allowed_time
#     537 with TimeoutGuard(remaining_time) as guard:
# --> 538     self.credentials.before_request(auth_request, method, url, request_headers)
#     539 remaining_time = guard.remaining_timeout
#     541 with TimeoutGuard(remaining_time) as guard:
#
# File ~/.local/lib/python3.10/site-packages/google/auth/credentials.py:175, in Credentials.before_request(self, request, method, url, headers)
#     171 # pylint: disable=unused-argument
#     172 # (Subclasses may use these arguments to ascertain information about
#     173 # the http request.)
#     174 if not self.valid:
# --> 175     self.refresh(request)
#     176 metrics.add_metric_header(headers, self._metric_header_for_usage())
#     177 self.apply(headers)
#
# File ~/.local/lib/python3.10/site-packages/google/oauth2/service_account.py:438, in Credentials.refresh(self, request)
#     436 else:
#     437     assertion = self._make_authorization_grant_assertion()
# --> 438     access_token, expiry, _ = _client.jwt_grant(
#     439         request, self._token_uri, assertion
#     440     )
#     441     self.token = access_token
#     442     self.expiry = expiry
#
# File ~/.local/lib/python3.10/site-packages/google/oauth2/_client.py:308, in jwt_grant(request, token_uri, assertion, can_retry)
#     284 """Implements the JWT Profile for OAuth 2.0 Authorization Grants.
#     285
#     286 For more details, see `rfc7523 section 4`_.
#    (...)
#     304 .. _rfc7523 section 4: https://tools.ietf.org/html/rfc7523#section-4
#     305 """
#     306 body = {"assertion": assertion, "grant_type": _JWT_GRANT_TYPE}
# --> 308 response_data = _token_endpoint_request(
#     309     request,
#     310     token_uri,
#     311     body,
#     312     can_retry=can_retry,
#     313     headers={
#     314         metrics.API_CLIENT_HEADER: metrics.token_request_access_token_sa_assertion()
#     315     },
#     316 )
#     318 try:
#     319     access_token = response_data["access_token"]
#
# File ~/.local/lib/python3.10/site-packages/google/oauth2/_client.py:279, in _token_endpoint_request(request, token_uri, body, access_token, use_json, can_retry, headers, **kwargs)
#     268 response_status_ok, response_data, retryable_error = _token_endpoint_request_no_throw(
#     269     request,
#     270     token_uri,
#    (...)
#     276     **kwargs
#     277 )
#     278 if not response_status_ok:
# --> 279     _handle_error_response(response_data, retryable_error)
#     280 return response_data
#
# File ~/.local/lib/python3.10/site-packages/google/oauth2/_client.py:72, in _handle_error_response(response_data, retryable_error)
#      69 except (KeyError, ValueError):
#      70     error_details = json.dumps(response_data)
# ---> 72 raise exceptions.RefreshError(
#      73     error_details, response_data, retryable=retryable_error
#      74 )
#
# RefreshError: ('invalid_grant: Invalid JWT Signature.', {'error': 'invalid_grant', 'error_description': 'Invalid JWT Signature.'})
